# %% [markdown]
# # Gradient Descent Exercises

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import log

# %% [markdown]
# ## Implementing Gradient Descent Algorithm

# %%
def gradient_descent(derivative_func,learning_rate=0.02,initial_value=0.5, precision=0.001,max_iter=300):
    x=initial_value
    x_list=[]

    for i in range(1,max_iter+1):
        x_list.append(x)
        print(x,derivative_func(x),learning_rate * derivative_func(x))
        x = x - learning_rate * derivative_func(x)
        
        if abs(learning_rate * derivative_func(x))<=precision:
        #if derivative_func(x)==0:
            break
        
    return x,x_list,i

# %% [markdown]
# ## Problem 1
# ### $$ g(x)=x^4-4x^2+5 $$
#
# ### $$ \frac{dg(x)}{dx}=4x^3-8x $$

# %%
#Implementing the function g(x)
def g(x):
    return x**4-4*x**2+5

#Implementing the derivative of the function g(x)
def dg(x):
    return 4*x**3-8*x

# %%
#Making data. 
#The linspace function returns evenly spaced numbers over a specified interval.
x_1=np.linspace(-2,2,1000)
#type(x_1)
#x_1

# %%
#Visualizing the function
plt.figure(figsize=(8,5))
plt.plot(x_1,g(x_1))
plt.xlabel('x', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.title('Cost function')
plt.show()

# %%
#Setting parameters: initial_value= 0.5, learning_rate= 0.02, precision= 0.0001, max_iter= 1000
local_minima,x_list,runs=gradient_descent(dg, initial_value=0.5, learning_rate=0.07, max_iter=1000, precision=0.0001)
print('Local minima occurs at', local_minima)
print('Cost at this point is', g(local_minima))
print('Slope at this point is', dg(local_minima))
print('Loop runs this many times:', runs)
# Out:
# 0.5 -3.5 -0.24500000000000002
# 0.745 -4.3060255000000005 -0.30142178500000005
# 1.0464217850000002 -3.78805292206187 -0.2651637045443309
# 1.311585489544331 -1.4676300805521247 -0.10273410563864874
# 1.41431959518298 0.001696715762228962 0.00011877010335602734
# Local minima occurs at 1.4142008250796239
# Cost at this point is 1.0000000012978973
# Slope at this point is -0.00020379394226566205
# Loop runs this many times: 5

# %%
#Plotting search trace on cost function
plt.figure(figsize=(8,5))
plt.plot(x_1,g(x_1))
plt.xlabel('x', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.title('Cost function')
plt.scatter(x_list,g(np.array(x_list)), color='red',alpha=0.4)
plt.show()

# %% [markdown]
# ### TASK FOR YOU
# Repeat after making the following changes and observe the results:
#
# 1. In implementation of gradient descent, replace the statment 'if abs(learning_rate * derivative_func(x))<=precision:' with 'if derivative_func(x_old)==0:'. Now the calling code again and observe the results.
# 2. Change initial value to -0.5, 1.5, 5, 50, 0.
# 3. Change learning rate to 0.002, 0.2, 2.

# %% [markdown]
# ### Max Float Value in Python

# %%
import sys
sys.float_info.max
#This is the max value of float that can be habdled by the machine.
# Out:
# 1.7976931348623157e+308

# %%
#plotting cost function against iterations

#Low learning rate (0.0005)
low_local_minimum,low_x_list,low_runs=gradient_descent(dg,initial_value=3,precision=0.0001,
                                                       max_iter=100,learning_rate=0.0005)
n=list(range(1,101))
plt.figure(figsize=(15,10))
plt.plot(n,g(np.array(low_x_list)),color='lightgreen')
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Cost function', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.scatter(n,g(np.array(low_x_list)), color='lightgreen',alpha=0.8)

#Medium learning rate (0.001)
mid_local_minimum,mid_x_list,mid_runs=gradient_descent(dg,initial_value=3,precision=0.0001,
                                                       max_iter=100,learning_rate=0.001)
n=list(range(1,101))
plt.plot(n,g(np.array(mid_x_list)),color='hotpink')
plt.scatter(n,g(np.array(mid_x_list)), color='hotpink',alpha=0.8)

#High learning rate (0.002)
high_local_minimum,high_x_list,high_runs=gradient_descent(dg,initial_value=3,precision=0.0001,
                                                          max_iter=100,learning_rate=0.002)
n=list(range(1,101))
plt.plot(n,g(np.array(high_x_list)),color='steelblue')
plt.scatter(n,g(np.array(high_x_list)), color='steelblue',alpha=0.8)

#Very very high learning rate (0.25)
insane_local_minimum,insane_x_list,insane_runs=gradient_descent(dg,initial_value=1.9,precision=0.0001,
                                                                max_iter=100,learning_rate=0.25)
n=list(range(1,101))
plt.plot(n,g(np.array(insane_x_list)),color='red')
plt.scatter(n,g(np.array(insane_x_list)), color='red',alpha=0.8)

plt.legend(['0.0005','0.001','0.002','0.25'],title='Learning Rate',title_fontsize=14, fontsize=18)
plt.show()
# Out:
# 3 84 0.042
# 2.958 79.86320764800001 0.03993160382400001
# 2.9180683961760003 76.046300017135 0.0380231500085675
# 2.8800452461674326 72.51562957914652 0.03625781478957326
# 2.8437874313778595 69.24198050975954 0.034620990254879774
# 2.8091664411229798 66.19987352705733 0.03309993676352867
# 2.7760665043594512 63.36699634804325 0.03168349817402163
# 2.7443830061854295 60.72373422340968 0.03036186711170484
# 2.7140211390737248 58.252780751219824 0.029126390375609913
# 2.684894748698115 55.93881350353632 0.027969406751768164
# 2.656925341946347 53.76822229829764 0.02688411114914882
# 2.630041230797198 51.72888047888769 0.025864440239443846
# 2.604176790557754 49.80995151912524 0.02490497575956262
# 2.5792718147981915 48.00172479299634 0.024000862396498172
# 2.555270952401693 46.29547554040093 0.023147737770200464
# 2.532123214631493 44.68334499975656 0.022341672499878278
# 2.5097815421316145 43.15823742334807 0.021579118711674034
# 2.4882024234199407 41.7137312854513 0.020856865642725653
# 2.467345557777215 40.34400246960749 0.020172001234803744
# 2.447173556542411 39.043757605300215 0.01952187880265011
# 2.4276516777397608 37.80817603515217 0.018904088017576086
# 2.408747589722185 36.6328591466809 0.01831642957334045
# 2.3904311601488444 35.51378600934986 0.01775689300467493
# 2.3726742671441694 34.44727442729727 0.017223637213648637
# 2.355450629930521 33.42994665792973 0.016714973328964867
# 2.338735656601556 32.458699162236336 0.016229349581118168
# 2.3225063070204377 31.530675848737044 0.015765337924368523
# 2.306740969096069 30.64324435304255 0.015321622176521275
# 2.291419346919548 29.793974961965827 0.014896987480982914
# 2.276522359438565 28.98062184732141 0.014490310923660705
# 2.2620320485149046 28.20110632185864 0.01410055316092932
# 2.247931495353975 27.453501869729756 0.013726750934864878
# 2.23420474441911 26.73602073773792 0.013368010368868961
# 2.220836734050241 26.04700190235975 0.013023500951179875
# 2.207813233099061 25.38490025202916 0.01269245012601458
# 2.1951207829730466 24.748276845089016 0.012374138422544508
# 2.182746644550502 24.13579012173349 0.012067895060866744
# 2.1706787494896354 23.546187963645295 0.011773093981822648
# 2.1589056555078128 22.978300508271577 0.011489150254135789
# -1.9055380926520056 -12.432305398613526 -3.1080763496533814
# 1.2025382570013758 -2.664352134033913 -0.6660880335084782
# 1.868626290509854 11.150199314983896 2.787549828745974
# -0.9189235382361198 4.247556924901806 1.0618892312254515
# -1.9808127694615714 -15.24131811893894 -3.810329529734735
# 1.8295167602731637 9.858399187221993 2.4645997968054982
# -0.6350830365323346 4.056070950846978 1.0140177377117445
# -1.649100774244079 -4.746332108110762 -1.1865830270276905
# -0.4625177472163886 3.3043698585969707 0.8260924646492427
# -1.2886102118656313 1.749848763084266 0.4374621907710665
# -1.7260724026366978 -6.761549906971053 -1.6903874767427634
# -0.03568492589393446 0.2852976404237139 0.07132441010592848
# -0.10700933599986294 0.8511732332326365 0.21279330830815912
# -0.3198026443080221 2.427591515604033 0.6068978789010082
# -0.9267005232090303 4.230299445204426 1.0575748613011065
# -1.9842753845101369 -15.376934152684889 -3.8442335381712223
# 1.8599581536610854 10.858021550666628 2.714505387666657
# -0.8545472340055715 4.340242068279071 1.0850605170697678
# -1.9396077510753393 -13.670962356364264 -3.417740589091066
# 1.4781328380157266 1.0930892070912854 0.27327230177282136
# 1.2048605362429052 -2.6425535670478206 -0.6606383917619552
# 1.8654989280048604 11.04439725380884 2.76109931345221
# -0.8956003854473498 4.29135862630833 1.0728396565770826

# %% [markdown]
# ## Problem 2
# ### $$ h(x)=x^5-2x^4+2 $$
# ### $$ \frac{dh(x)}{dx}=5x^4-8x $$

# %%
#Implementing the function h(x)
def h(x):
    return x**5-2*x**4+2

#Implementing the derivative of the function h(x)
def dh(x):
    return 5*x**4-8*x**3

#Making data
x_2=np.linspace(-2.5,2.5,1000)

#Visualizing the function
plt.figure(figsize=(8,5))
plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)
plt.plot(x_2,h(x_2))
plt.xlabel('x', fontsize=14)
plt.ylabel('h(x)', fontsize=14)
plt.title('Cost function')
plt.show()

# %%
#Running gradient descent and plotting the results
local_minima,x_list,runs=gradient_descent(dh,initial_value= 1, learning_rate= 0.02, precision= 0.001,max_iter= 20)
    
print('Local minima occures at ', local_minima)
print('Cost at this point is ', h(local_minima))
print('Slope at this point is ', dh(local_minima))
print('Loop runs this many times: ', runs)

plt.figure(figsize=(8,5))
plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)
plt.plot(x_2,h(x_2))
plt.xlabel('x', fontsize=14)
plt.ylabel('h(x)', fontsize=14)
plt.title('Cost function')
plt.scatter(x_list,h(np.array(x_list)), color='red',alpha=0.4)
plt.show()
# Out:
# 1 -3 -0.06
# 1.06 -3.2157431999999986 -0.06431486399999997
# 1.124314864 -3.3802859648066317 -0.06760571929613264
# 1.1919205832961326 -3.455068428663049 -0.06910136857326098
# 1.2610219518693935 -3.3986740809141427 -0.06797348161828286
# 1.3289954334876763 -3.180658770303321 -0.06361317540606642
# 1.3926086088937428 -2.8005798244822913 -0.05601159648964583
# 1.4486202053833888 -2.300920065170601 -0.04601840130341202
# 1.4946386066868007 -1.758976743078847 -0.03517953486157694
# 1.5298181415483776 -1.2563605441418453 -0.025127210882836905
# 1.5549453524312145 -0.8469445799283832 -0.016938891598567665
# 1.5718842440297822 -0.54598593091902 -0.0109197186183804
# 1.5828039626481627 -0.3409414240241091 -0.006818828480482182
# 1.589622791128645 -0.20841683912572506 -0.004168336782514501
# 1.5937911279111594 -0.12568311385472697 -0.0025136622770945394
# 1.5963047901882539 -0.07515477126761283 -0.0015030954253522565
# Local minima occures at  1.5978078856136062
# Cost at this point is  -0.6213909277530139
# Slope at this point is  -0.044710229297194815
# Loop runs this many times:  16

# %% [markdown]
# ### TASK FOR YOU
# Repeat after making the following changes and observe the results:
# 1. initial_value= -0.8, max_iter= 8
# 2. initial_value= -0.8, learning_rate= 0.02, precision= 0.001,max_iter= 9

# %% [markdown]
# ## Problem 3
# The following cost function has 2 parameters.
# ### $$ f(x,y)=\frac{1}{3^{-x^2-y^2}+1} $$

# %%
#Implementing the function h(x)
def f(x,y):
    return 1/(3**(-x**2-y**2)+1)

#Making data for x and y
x_3=np.linspace(-2,2,200)
y_3=np.linspace(-2,2,200)
x_3,y_3=np.meshgrid(x_3,y_3) 
#meshgrid converts x_3 and y_3 into 2D arrays, as required by the plotting function plot_surface.

# %%
#Plotting a 3D graph
fig=plt.figure(figsize=[16,12])
ax=plt.axes(projection='3d')
ax.set_xlabel('x', fontsize=16)
ax.set_ylabel('y', fontsize=16)
ax.set_zlabel('Cost - f(x,y)', fontsize=16)
ax.plot_surface(x_3,y_3,f(x_3,y_3), alpha=0.4, cmap='summer') 
#Explore other colormaps
#Website for color choices: materialpalette.com
plt.show()

# %% [markdown]
# ### Partial derivatives for $$ f(x,y)=\frac{1}{3^{-x^2-y^2}+1} $$ w.r.t. x and y
#
# $$ \frac{\partial f(x,y)}{\partial dx} = \frac{2x.ln(3).3^{-x^2-y^2}}{({3^{-x^2-y^2}}+1)^2} $$
# $$ \frac{\partial f(x,y)}{\partial dy} = \frac{2y.ln(3).3^{-x^2-y^2}}{({3^{-x^2-y^2}}+1)^2} $$
#
# Use online tools for finsing derivatives.
# One website is https://www.symbolab.com/solver/derivative-calculator

# %%
#Implementing partial derivatives
def pdfx(x,y):
    return 2*x*log(3)*(3**(-x**2-y**2))/(3**(-x**2-y**2)+1)**2
def pdfy(x,y):
    return 2*y*log(3)*(3**(-x**2-y**2))/(3**(-x**2-y**2)+1)**2

# %%
#Custom implementation of gradient descent for two parameters
learning_rate = 0.1
max_iter = 2000
initial_x = 1.8
initial_y=1.0

x_old=initial_x
y_old=initial_y

x_list=[]
y_list=[]
for i in range (1,max_iter+1):
    x_new = x_old - learning_rate * pdfx(x_old,y_old)
    y_new = y_old - learning_rate * pdfy(x_old,y_old)
    
    x_list.append(x_old)
    y_list.append(y_old)

    x_old=x_new
    y_old=y_new

# %%
#Plotting the 3D graph
fig=plt.figure(figsize=[16,12])
ax=plt.axes(projection='3d')
ax.set_xlabel('x', fontsize=16)
ax.set_ylabel('y', fontsize=16)
ax.set_zlabel('Cost - f(x,y)', fontsize=16)
ax.plot_surface(x_3,y_3,f(x_3,y_3), alpha=0.4, cmap='summer')
x_list=np.array(x_list)
y_list=np.array(y_list)
ax.scatter(x_list,y_list,f(x_list,y_list), alpha=0.4, s=50, color='red')
plt.show()
